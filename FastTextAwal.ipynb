# %%
import pandas as pd
import re
import numpy as np
import joblib
import pickle
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('coba.csv')

# %%
#konversi label ke polaritas
def convert(polarity):
    if polarity == 'positif':
        return 1
    elif polarity == 'netral':
        return 0
    else:
        return -1

# %%
df['Polarity'] = df['Label'].apply(convert)

# %%
X = df['STOP_REMOVAL']
y = df['Polarity']

# %%
df
# Out:
#                                            STOP_REMOVAL    Label  Polarity
# 0      cnnindonesia aneh harga bbm tgl 3 09 kagetnya...  negatif        -1
# 1     ujung microfon berbunyi rakyat cengeng ujung m...  negatif        -1
# 2      cnnindonesia sih gak pake sistem kupon aja yg...  negatif        -1
# 3     politkus irwan pd adian pdip bersiteru kenaika...   netral         0
# 4     vacum cleaner han river 179rb aja lupa gratis ...   netral         0
# ...                                                 ...      ...       ...
# 1662             jisundae idih mahalan pertamax 1 liter  negatif        -1
# 1663   prfmnews ku dah pakai puas banget dah tuh viv...  positif         1
# 1664   patraniagarjbt jawabannya c pertamax turbo se...   netral         0
# 1665   jokowi seliter pertamax 20kg tomat kubis 3 5k...  negatif        -1
# 1666                            senapav pertamax liter    netral         0
#
# [1667 rows x 3 columns]

# %%
import os

import pandas as pd
from tqdm.auto import tqdm

from nltk.tokenize import word_tokenize
from gensim.models import FastText

# %%
sentences = [word_tokenize(STOP_REMOVAL.lower()) for STOP_REMOVAL in tqdm(df.STOP_REMOVAL)]
sentences[:5]
# Out:
#   0%|          | 0/1667 [00:00<?, ?it/s]
# [['cnnindonesia',
#   'aneh',
#   'harga',
#   'bbm',
#   'tgl',
#   '3',
#   '09',
#   'kagetnya',
#   'kagetnya',
#   'kena',
#   'heart',
#   'attack'],
#  ['ujung',
#   'microfon',
#   'berbunyi',
#   'rakyat',
#   'cengeng',
#   'ujung',
#   'mulut',
#   'pejabat',
#   'berbunyi',
#   'postur',
#   'apbn',
#   'tersandra',
#   'subsidi',
#   'memberatkan',
#   'keuangan',
#   'pemerintah',
#   'keputusan',
#   'bbm',
#   'dihindari',
#   'hayo',
#   'yg',
#   'cengeng'],
#  ['cnnindonesia',
#   'sih',
#   'gak',
#   'pake',
#   'sistem',
#   'kupon',
#   'aja',
#   'yg',
#   'dikasihkan',
#   'bayar',
#   'pajak',
#   'kendaraan',
#   'kupon',
#   'dikasih',
#   'brp',
#   'liter',
#   'jatah',
#   'bbm',
#   'disobek',
#   'operator',
#   'ngisi',
#   'spbu',
#   'liter',
#   'bbm',
#   'yg',
#   'diisi',
#   'pertamina'],
#  ['politkus',
#   'irwan',
#   'pd',
#   'adian',
#   'pdip',
#   'bersiteru',
#   'kenaikan',
#   'harga',
#   'bbm',
#   'https',
#   't',
#   'co',
#   'qwbpf4oigk'],
#  ['vacum',
#   'cleaner',
#   'han',
#   'river',
#   '179rb',
#   'aja',
#   'lupa',
#   'gratis',
#   'ongkir',
#   '0',
#   'rupiah',
#   'cashback',
#   'shopee',
#   'yuk',
#   'gercep',
#   'bbm',
#   'appleevent',
#   'nctdream',
#   'https',
#   't',
#   'co',
#   '4amnqykgve']]

# %% [markdown]
# # Train FastText Model

# %%
model = FastText(sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=1000, sg=0, hs=0)

# %%
model.save("coba.fasttext")

# %% [markdown]
# # Load

# %%
model = FastText.load("coba.fasttext")

# %% [markdown]
# # continue training

# %%
contoh_data = [
    ['bener', 'yak', 'pertalite', 'berasa', 'boros', 'banget'],
    ["perwarna", "mempengaruhi", "kualitas", "pertalite"],
    ["pertamina", "jamin", "kualitas", "pertalite", "sesuai", "aturan" , "pemerintah", "semoga", "berjalan", "sesuai", "harapan"]
]

# %%
model.train(contoh_data, total_examples=len(contoh_data), epochs=1)
# Out:
# (17, 21)

# %%
model.save("coba.fasttext")

# %%
w2v = model.wv

# %%
w2v.index_to_key
# Out:
# ['pertalite',
#  'bbm',
#  't',
#  'https',
#  'co',
#  'pertamax',
#  'harga',
#  'yg',
#  'kenaikan',
#  'subsidi',
#  'pertamina',
#  'rakyat',
#  'beli',
#  'ya',
#  'pemerintah',
#  'isi',
#  'aja',
#  'ga',
#  'solar',
#  'turun',
#  'bensin',
#  'tarif',
#  'kualitas',
#  'gak',
#  'mobil',
#  'pake',
#  'minyak',
#  'nya',
#  'kalo',
#  'rp',
#  'liter',
#  'motor',
#  'masyarakat',
#  'orang',
#  'boros',
#  'akap',
#  '1',
#  '2',
#  'jokowi',
#  'jenis',
#  'udah',
#  'sesuai',
#  '000',
#  'spbu',
#  'ngisi',
#  'penyesuaian',
#  'serba',
#  'indonesia',
#  'tolak',
#  'mmc',
#  'bersubsidi',
#  'serbi',
#  'bahan',
#  'full',
#  'demo',
#  'mahal',
#  'dasar',
#  'kota',
#  'ron',
#  'dunia',
#  'pakai',
#  'aturan',
#  'si',
#  'rt',
#  'tp',
#  'kaya',
#  'amp',
#  'bakar',
#  'antri',
#  'subsiditepatsasaran',
#  'jamin',
#  'salah',
#  'tau',
#  '3',
#  'nih',
#  'angkutan',
#  'bltbbmtepatsasaran',
#  'bantuanbbmuntukrakyat',
#  'negara',
#  'menaikkan',
#  'islamkaffah',
#  'turbo',
#  'mahasewa',
#  'bohir',
#  'klo',
#  'lu',
#  'kawal',
#  '10',
#  'sih',
#  'mengerek',
#  'premium',
#  'mahasiswakawalsubsidi',
#  'blt',
#  'provinsi',
#  'cnnindonesia',
#  'kendaraan',
#  'dr',
#  'emang',
#  'murah',
#  'vivo',
#  'resmi',
#  'ikutan',
#  'gt',
#  '2022',
#  '5',
#  'harganya',
#  'gue',
#  'skrg',
#  'bgt',
#  'aksi',
#  'allah',
#  'pas',
#  'sembako',
#  'jd',
#  '500',
#  'bus',
#  'yuk',
#  'jg',
#  'bjorka',
#  'gw',
#  'banget',
#  'dgn',
#  'pewarna',
#  'ngantri',
#  'pom',
#  'itb',
#  'pakar',
#  'bikin',
#  'rugi',
#  'mah',
#  'sasaran',
#  'coba',
#  'presiden',
#  'ppnjatimbalinus',
#  'patraniaga',
#  'biar',
#  'udh',
#  'didu',
#  'tuh',
#  'b',
#  'dapet',
#  'melambung',
#  'menteri',
#  'utk',
#  'krn',
#  'uang',
#  'abis',
#  'jalan',
#  'shell',
#  '89',
#  'batalkan',
#  'zat',
#  'dukung',
#  'km',
#  'tank',
#  'langsung',
#  'menolak',
#  'sampe',
#  'official',
#  '92',
#  'jeniusjatimbalinus',
#  'kebijakan',
#  'jual',
#  'memengaruhi',
#  'org',
#  'lo',
#  'ekonomi',
#  'berita',
#  'bumn',
#  'simak',
#  'barat',
#  'sengsarakan',
#  'miskin',
#  '30',
#  'beda',
#  'kerja',
#  'antrian',
#  'listrik',
#  'kali',
#  'msaid',
#  'warga',
#  'erickthohir',
#  'habis',
#  'bem',
#  'fasilitas',
#  'sby',
#  'iya',
#  'semoga',
#  'isu',
#  'pagi',
#  'data',
#  'pasar',
#  'mendukung',
#  '7',
#  'dah',
#  'kemarin',
#  'jawabannya',
#  'gk',
#  '14',
#  '4',
#  '00',
#  'doang',
#  'ribu',
#  'trus',
#  'pengalihan',
#  'hidup',
#  'sda',
#  '90',
#  'nggak',
#  'dpr',
#  'cuman',
#  '12',
#  'd',
#  'beralih',
#  'kl',
#  'pks',
#  'lg',
#  'asli',
#  'september',
#  'ku',
#  'susah',
#  'kapitalisasi',
#  'detikcom',
#  'wa',
#  'mas',
#  'bilang',
#  'ojol',
#  'sdh',
#  'minggu',
#  '6',
#  'anggota',
#  'tdk',
#  'gimana',
#  'subsidibagikaumrentan',
#  'bansosharus',
#  'tepatsasaran',
#  'setuju',
#  'mahasiswa',
#  'bayar',
#  'jgn',
#  'sambo',
#  'rumah',
#  'minum',
#  'alphard',
#  'mesin',
#  'ri',
#  'askrlfess',
#  'gini',
#  'hati',
#  'gara',
#  'pindah',
#  'duit',
#  'eceran',
#  'video',
#  'lbh',
#  'bener',
#  'tinggal',
#  'alasan',
#  'dpt',
#  'ganti',
#  'dg',
#  'bantuan',
#  'anak',
#  'gua',
#  'dialihkan',
#  'cari',
#  'mikir',
#  'gas',
#  'loh',
#  'kasih',
#  '33',
#  'demokrat',
#  'wkwk',
#  'unjuk',
#  'kek',
#  'produk',
#  'sy',
#  'hr',
#  'erick',
#  'jakarta',
#  'kkpaccelerate',
#  'saktiwahyutrenggono',
#  'bansos',
#  'deh',
#  'eh',
#  'bagus',
#  'sosial',
#  'bangkitatautertindas',
#  'terdampak',
#  'kosong',
#  'ikn',
#  'hacker',
#  'jualan',
#  'cepat',
#  'rupiah',
#  'sulit',
#  'lihat',
#  'diisi',
#  'bbmuntuknelayan',
#  'sbyfess',
#  '150',
#  'untung',
#  'penyaluran',
#  'naiknya',
#  'nangis',
#  'irit',
#  'liat',
#  'aman',
#  'thohir',
#  'setara',
#  'persen',
#  '650',
#  'zalim',
#  'berasa',
#  'selengkapnya',
#  'gitu',
#  '17',
#  'malaysia',
#  'konsumsi',
#  'beat',
#  'bos',
#  'ganjarpranowo',
#  'menengah',
#  'hrg',
#  'mypertamina',
#  'univ',
#  'biaya',
#  'kayak',
#  'dikit',
#  'nelayan',
#  'mewah',
#  'id',
#  'cepet',
#  'masuk',
#  'guys',
#  's',
#  'yaa',
#  'dampak',
#  'gila',
#  'mending',
#  'rendah',
#  'mu',
#  'pendapatan',
#  'dijual',
#  'rezim',
#  'mantap',
#  'terkait',
#  'goblok',
#  'pejabat',
#  'kondisi',
#  'kebutuhan',
#  'wib',
#  'hasil',
#  'lampung',
#  'merah',
#  'ngga',
#  'kegiatan',
#  'info',
#  'naikin',
#  'buruh',
#  '20',
#  'solusi',
#  'jaman',
#  'penjelasan',
#  'democrazymedia',
#  'jawa',
#  'dll',
#  'karna',
#  'ltr',
#  'super',
#  'skrng',
#  'fra050879',
#  'gara2',
#  'patraniagarjbt',
#  'naek',
#  'bau',
#  'kaga',
#  'anjlok',
#  'l',
#  'kemenbumn',
#  'pokok',
#  'hbd',
#  'alihsubsidiinflasiterkendali',
#  '100',
#  'tpi',
#  'pengguna',
#  'sedih',
#  'dlm',
#  'ditengah',
#  'kaget',
#  'kuota',
#  'waras',
#  'subsidibagi',
#  'yanglayak',
#  'buka',
#  'non',
#  'fulltank',
#  'msh',
#  'desa',
#  '800',
#  'juta',
#  'bang',
#  'hbd21demokrat',
#  'mentah',
#  'papua',
#  'kec',
#  'heran',
#  'polwan',
#  'g',
#  '10rb',
#  'tvonenews',
#  'dilarang',
#  'makan',
#  'pengunjuk',
#  'damai',
#  'ngerti',
#  'aplikasi',
#  'malu',
#  'hrs',
#  'negeri',
#  'online',
#  'kampus',
#  'mari',
#  'geloraco',
#  'keren',
#  '9',
#  'kemana',
#  'angkot',
#  'enak',
#  '80',
#  'sms',
#  'produksi',
#  'pd',
#  'pdhl',
#  'kau',
#  'pilihan',
#  'butuh',
#  'aneh',
#  'tuku',
#  'bela',
#  'dimana',
#  'cc',
#  'yo',
#  'sepeda',
#  'mudah',
#  'trs',
#  'pengamanan',
#  'sistem',
#  'subsidinya',
#  'bs',
#  'bangkitbersamaet',
#  'pengabdian',
#  'knp',
#  'srikandiabdinegeri',
#  'tuntutannya',
#  'menyuarakan',
#  'spontan',
#  'simpatik',
#  'humanis',
#  'cm',
#  'wkwkwk',
#  'kang',
#  'malkot',
#  'berdampak',
#  'skema',
#  'w',
#  'pajak',
#  'apbn',
#  'otak',
#  'hoax',
#  '09',
#  'medan',
#  'ayo',
#  'polrestabes',
#  'perubahan',
#  'baca',
#  'mo',
#  'ikuti',
#  'make',
#  '40',
#  'utang',
#  'proyek',
#  'pasca',
#  'hutang',
#  '50rb',
#  'bawa',
#  '25',
#  'ko',
#  'sumberlawang',
#  'populer',
#  'blm',
#  'loe',
#  '13',
#  'gabisa',
#  'tangki',
#  'kelas',
#  'pembatasan',
#  'tol',
#  '15',
#  'disubsidi',
#  'muslim',
#  'anggaran',
#  'gede',
#  'ahmad',
#  'gaes',
#  'gaji',
#  'jelek',
#  'fyi',
#  'elit',
#  'tetep',
#  'beban',
#  '900',
#  'mobilnya',
#  'its',
#  'korupsi',
#  'sehari',
#  'ah',
#  'giliran',
#  'dpn',
#  'kak',
#  'berjalan',
#  'aj',
#  'program',
#  'follow',
#  'gegara',
#  'akibat',
#  'nusa',
#  'terjamin',
#  'disuruh',
#  'tanyakanrl',
#  'lho',
#  'ongkos',
#  'berani',
#  'triliun',
#  'user',
#  'kmrn',
#  'kasian',
#  'selisih',
#  'sm',
#  'kuda',
#  'plat',
#  'kereta',
#  'strip',
#  'pribadi',
#  'bu',
#  'dinaikkan',
#  'transportasi',
#  '8',
#  'kadrun',
#  '95',
#  'penuh',
#  'sebulan',
#  'antrean',
#  'database',
#  'mekanisme',
#  'berubah',
#  'usaha',
#  'paham',
#  'krisis',
#  'khusus',
#  'daerah',
#  'anies',
#  '11',
#  'bjorkanism',
#  'membeli',
#  'kepentingan',
#  'kecamatan',
#  'tunai',
#  'bupati',
#  'panas',
#  'pulang',
#  'suruh',
#  'protes',
#  'tenggara',
#  'petugas',
#  'terbaik',
#  '50',
#  'selesai',
#  'melaksanakan',
#  'kantor',
#  'gpp',
#  'r',
#  'prastow',
#  'lupa',
#  'ak',
#  'terima',
#  'sengaja',
#  'dana',
#  'trenggono',
#  'temen',
#  'kah',
#  'mohon',
#  'tawang',
#  'lancar',
#  'kendal',
#  'lingkungan',
#  'supra',
#  'up',
#  'a',
#  'hemat',
#  'mengumumkan',
#  'total',
#  'sibuk',
#  'sektor',
#  '17rb',
#  'maaf',
#  'kader',
#  'meroket',
#  'oposisicerdas',
#  'mempengaruhi',
#  'bnyk',
#  'rame',
#  'perkapita',
#  'pekerja',
#  'bpk',
#  'piye',
#  'brp',
#  'ketersediaan',
#  'sok',
#  'males',
#  'dikasih',
#  '10k',
#  'publik',
#  'faktor',
#  'c',
#  'pen',
#  'emg',
#  'penggunaan',
#  'era',
#  'mendorong',
#  'sajak',
#  'pengarang',
#  'tolong',
#  'pilih',
#  'jasa',
#  'besok',
#  'pusat',
#  'politik',
#  'keputusan',
#  'sygjoshua',
#  'ttp',
#  'ekowboy2',
#  'unpad',
#  'air',
#  'mrk',
#  'istana',
#  'mayoritas',
#  'alhamdulillah',
#  'y',
#  'jaya',
#  'barang',
#  'langka',
#  'ribut',
#  'barel',
#  'energi',
#  'islam',
#  'truk',
#  'nama',
#  'percaya',
#  'penurunan',
#  'anjing',
#  'an',
#  'harapan',
#  'yah',
#  'rp10',
#  'sepi',
#  'kelompok',
#  'terbaru',
#  'mengalami',
#  'khawatir',
#  'alextham878',
#  'ngerasain',
#  'self',
#  'n',
#  'ojek',
#  'pertalit',
#  'kemaren',
#  'anjir',
#  'kyk',
#  'bangsa',
#  'sesungguhnya',
#  'stopkebijakanzalim',
#  'kerasa',
#  'efek',
#  'minumnya',
#  'warna',
#  'iki',
#  'dinikmati',
#  'polsek',
#  'menilai',
#  'polisi',
#  'perjuangan',
#  'migas',
#  'tolakkenaikanbbm',
#  'fokus',
#  'nasi',
#  'turunkan',
#  'penumpang',
#  'jalur',
#  'dewan',
#  'massa',
#  'siang',
#  'memenuhi',
#  'tolakteruskenaikanbbm',
#  'rp159',
#  'dibatasi',
#  '50k',
#  'menurunkan',
#  'main',
#  'abu',
#  '15rb',
#  'pemimpin',
#  'boss',
#  'son',
#  'silahkan',
#  'sing',
#  'akses',
#  'sayang',
#  'rezeki',
#  'oh',
#  'tu',
#  'ih',
#  'bantu',
#  'kehancuran',
#  'geruduk',
#  'stop',
#  'noh',
#  'berbagi',
#  'dolar',
#  'seliter',
#  'dongok',
#  'paket',
#  'tulis',
#  'yaudah',
#  'hapus',
#  'bis',
#  'pergi',
#  'belom',
#  'hasilnya',
#  'order',
#  'mengisi',
#  'energizingyou',
#  'penolakan',
#  'btw',
#  'penguasa',
#  'takut',
#  'manusia',
#  'hak',
#  'naikkan',
#  'jebol',
#  'merasakan',
#  'ato',
#  '28',
#  'berat',
#  'syahirularif',
#  '7fc70daf',
#  'service',
#  'batu',
#  'areajulid',
#  'pertashop',
#  'menerima',
#  'mypertaminaid',
#  'terpaksa',
#  'mengurangi',
#  '300',
#  'tgl',
#  'memberatkan',
#  'sp150973',
#  'am170278',
#  'download',
#  'ir080483',
#  'akurniawan81',
#  'gratis',
#  'mulu',
#  'modal',
#  'revo',
#  'campur',
#  'sri',
#  'mulyani',
#  'naikjokowiturun',
#  'timur',
#  'al',
#  'wakil',
#  'perusahaan',
#  'yaaa',
#  'wkwkw',
#  'gocap',
#  'alasannya',
#  'dibandingkan',
#  'suara',
#  'bisnis',
#  'segitu',
#  'skr',
#  'pa',
#  'karyawan',
#  'revvo',
#  'konsumen',
#  'esdm',
#  'puji',
#  'kompastv',
#  'kudu',
#  'suka',
#  'senang',
#  'via',
#  'kompascom',
#  'bekasi',
#  'belinya',
#  'puan',
#  'imbas',
#  'dki',
#  'koramil',
#  '98',
#  'vadpqfuxx8',
#  'gedung',
#  'menyebut',
#  'plus',
#  'tampil',
#  'style',
#  'anime',
#  'distroartonline',
#  '081254533646',
#  '5268ba8f',
#  'raya',
#  'peduli',
#  'ngeluh',
#  'wow',
#  'pksejahtera',
#  'sbg',
#  'scoopy',
#  'u',
#  'klaim',
#  'puluhan',
#  '600',
#  'babinsa',
#  'akal',
#  'rokok',
#  'bali',
#  'cilacap',
#  'ppscmanteep',
#  'kesel',
#  'laku',
#  'mei',
#  'peseek',
#  'tanggal',
#  'ramlirizal',
#  'basuki',
#  'laksanakan',
#  'berdasarkan',
#  'btp',
#  'kepala',
#  'burhanmuhtadi',
#  'deket',
#  'mengikuti',
#  'sakit',
#  'ygy',
#  'wakanda',
#  'wajar',
#  'isinya',
#  'vespa',
#  'tni',
#  'dri',
#  'cek',
#  'pegawai',
#  'satunya',
#  'alias',
#  '200',
#  'android',
#  'pp',
#  'kualitasnya',
#  'oke',
#  'pssi',
#  'ratusan',
#  'bro',
#  'menjual',
#  'luhut',
#  'bandung',
#  'ampe',
#  'publish',
#  'pesan',
#  'dorong',
#  'tan',
#  'semenjak',
#  'testimoni',
#  'hmi',
#  'bensinnya',
#  'rusia',
#  'pb',
#  'nambah',
#  'of',
#  'demomu',
#  'beraksi',
#  'puanmaharani',
#  'petugasnya',
#  'mogok',
#  'em',
#  'senin',
#  'power',
#  'pemilik',
#  'dipake',
#  'cerdas',
#  'tv',
#  'situ',
#  'klu',
#  'dkknya',
#  'patroli',
#  'bapack',
#  'mental',
#  'beliau',
#  'iba',
#  'my',
#  'hubungannya',
#  'inflasi',
#  'ugm',
#  'tempodotco',
#  'sederhana',
#  'distribusi',
#  'ruhutsitompul',
#  'jkw',
#  'petani',
#  'ketimbang',
#  'wagimandeep212',
#  'budi',
#  'mar3m',
#  'blueprint',
#  'personel',
#  'kayaknya',
#  'pembakaran',
#  'lucu',
#  'kemenkeuri',
#  'kemampuan',
#  'dinaikin',
#  'mmegang',
#  'jarak',
#  'bismillah',
#  'milik',
#  'melawan',
#  'aliansi',
#  'selang',
#  'bemunj',
#  'bemkmipb',
#  'gamau',
#  'drpd',
#  'job',
#  'sehat',
#  'bemkm',
#  'asumsi',
#  'uyokback',
#  'diuntungkan',
#  'kalangan',
#  'bingung',
#  'driver',
#  'bolak',
#  'lumayan',
#  'lipat',
#  'serentak',
#  'tai',
#  'alihkan',
#  'bunga',
#  'srakah',
#  '2008',
#  'nyoba',
#  'sekian',
#  'dikurangi',
#  'kpm',
#  'kesempatan',
#  'jatim',
#  'opposite090l92',
#  'indon',
#  'polda',
#  'polres',
#  'petronas',
#  'meliputi',
#  'batang',
#  'beriman',
#  'ta',
#  'sikap',
#  'pikir',
#  'dibeli',
#  'petralite',
#  'bkn',
#  'stock',
#  'm',
#  'koruptor',
#  'cebong',
#  'berhak',
#  '70k',
#  'emak',
#  'kpd',
#  'wae',
#  'bp',
#  'golongan',
#  'motornya',
#  'nicke',
#  'utama',
#  'sindo',
#  'pgn',
#  '88',
#  'pemakaian',
#  'dipakai',
#  'discount',
#  ...]

# %%
w2v.vectors
# Out:
# array([[-2.4447005 ,  0.38866603,  0.37672967, ...,  1.2867795 ,
#          0.81431764, -1.4684907 ],
#        [ 0.27335292,  3.6972387 , -1.2054373 , ...,  1.9560343 ,
#         -0.23859046, -4.0134025 ],
#        [-0.8764195 , -3.610547  ,  0.20735052, ...,  0.9602518 ,
#         -6.5531483 ,  4.72069   ],
#        ...,
#        [-0.47349688, -0.25101486, -1.5101092 , ..., -0.97903115,
#          1.7281873 , -0.561441  ],
#        [ 0.91303647, -2.950142  ,  0.0106851 , ..., -0.56582695,
#         -0.4128766 , -0.9426125 ],
#        [-1.505813  ,  0.16642942, -2.9218552 , ..., -2.74374   ,
#          0.46773234,  2.734831  ]], dtype=float32)

# %%
w2v.vector_size
# Out:
# 128

# %%
w2v['bors']
# Out:
# array([-0.32934317,  0.13194421,  1.7841164 ,  2.8712351 ,  0.85983485,
#         0.08173323,  1.0975446 , -1.1098926 , -0.3323525 , -1.4257627 ,
#        -0.30924496, -0.7620231 ,  0.643226  ,  0.11476453,  0.02479601,
#         0.6762807 , -0.26347083, -0.4221569 , -0.26263303, -0.78151846,
#        -0.05224352, -0.16127706, -0.05865769,  0.4044252 ,  1.1383505 ,
#        -0.39765102, -1.1174088 , -0.7832413 ,  0.92423713, -1.27686   ,
#        -0.17428043, -0.535459  ,  0.15945543,  1.1996989 , -1.5231984 ,
#        -0.02527368, -0.036335  , -1.4201224 , -1.6868198 ,  0.52794284,
#         0.49762496,  0.6203728 ,  0.37035173, -0.82029915, -0.08250193,
#         0.01071899, -0.35286403, -1.0417243 ,  0.88634187, -0.24714045,
#         0.08475471, -0.2394288 ,  0.11060214, -0.30249366, -0.45246968,
#        -0.33020902, -0.58950585, -0.29829127,  0.7140607 , -1.2824175 ,
#        -0.37304568, -0.5985968 , -1.4454706 ,  0.14881273,  0.7175496 ,
#         0.38913494,  0.9395324 , -0.32815695,  0.7425713 ,  0.30475578,
#         0.3453394 , -0.987785  , -0.5156783 ,  0.00360253, -0.41892022,
#         1.428185  , -1.0263839 ,  0.6903266 , -0.2822743 ,  0.6947897 ,
#        -1.1858829 ,  0.32255813,  1.590805  ,  0.6172377 ,  1.3291116 ,
#         0.6604874 ,  0.3340014 , -1.6942823 ,  0.6134769 , -1.666982  ,
#        -0.803018  , -1.0267694 ,  0.35685885,  0.65508634, -0.81033486,
#        -0.33945876, -1.3999884 ,  0.2674974 , -0.16491997, -0.49198428,
#        -0.9415905 , -0.08484332,  0.36769128, -0.15946737,  1.0468811 ,
#         0.23893261,  1.2848425 ,  0.9179908 , -1.2566248 , -0.08489933,
#         0.61944157, -0.6738717 ,  1.0049922 , -0.74905664, -0.7086975 ,
#         0.6127392 ,  0.15115091,  0.04516629,  1.5048971 , -1.7589796 ,
#        -0.12388086, -0.37065214,  0.24001732, -0.36428687, -0.2942105 ,
#         0.16937928, -0.32657036, -0.93982667], dtype=float32)

# %% [markdown]
# # similiar word

# %%
w2v.similar_by_word("bors", topn=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10624/3586044718.py in <module>
# ----> 1 w2v.similar_by_word("bors", topn=5)
#
# NameError: name 'w2v' is not defined

# %% [markdown]
# # higher order visualitation

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
X = UMAP().fit_transform(w2v.vectors)

# %%
df = pd.DataFrame(X, columns=["umap1", "umap2"])
df["text"] = w2v.index_to_key

# %%
fig = px.scatter(df, x="umap1", y="umap2", text="text")
fig.update_traces(textposition='top center')
fig.update_layout(
    height=800,
    title_text='Reduced FastText Visualisation'
)
fig.show()
# Out:
# <div>                            <div id="7c91cddf-cbe5-48b1-a84c-7dd1d70a4760" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c91cddf-cbe5-48b1-a84c-7dd1d70a4760")) {                    Plotly.newPlot(                        "7c91cddf-cbe5-48b1-a84c-7dd1d70a4760",                        [{"hovertemplate":"umap1=%{x}<br>umap2=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":["pertalite","bbm","t","https","co","pertamax","harga","yg","kenaikan","subsidi","pertamina","rakyat","beli","ya","pemerintah","isi","aja","ga","solar","turun","bensin","tarif","kualitas","gak","mobil","pake","minyak","nya","kalo","rp","liter","motor","masyarakat","orang","boros","akap","1","2","jokowi","jenis","udah","sesuai","000","spbu","ngisi","penyesuaian","serba","indonesia","tolak","mmc","bersubsidi","serbi","bahan","full","demo","mahal","dasar","kota","ron","dunia","pakai","aturan","si","rt","tp","kaya","amp","bakar","antri","subsiditepatsasaran","jamin","salah","tau","3","nih","angkutan","bltbbmtepatsasaran","bantuanbbmuntukrakyat","negara","menaikkan","islamkaffah","turbo","mahasewa","bohir","klo","lu","kawal","10","sih","mengerek","premium","mahasiswakawalsubsidi","blt","provinsi","cnnindonesia","kendaraan","dr","emang","murah","vivo","resmi","ikutan","gt","2022","5","harganya","gue","skrg","bgt","aksi","allah","pas","sembako","jd","500","bus","yuk","jg","bjorka","gw","banget","dgn","pewarna","ngantri","pom","itb","pakar","bikin","rugi","mah","sasaran","coba","presiden","ppnjatimbalinus","patraniaga","biar","udh","didu","tuh","b","dapet","melambung","menteri","utk","krn","uang","abis","jalan","shell","89","batalkan","zat","dukung","km","tank","langsung","menolak","sampe","official","92","jeniusjatimbalinus","kebijakan","jual","memengaruhi","org","lo","ekonomi","berita","bumn","simak","barat","sengsarakan","miskin","30","beda","kerja","antrian","listrik","kali","msaid","warga","erickthohir","habis","bem","fasilitas","sby","iya","semoga","isu","pagi","data","pasar","mendukung","7","dah","kemarin","jawabannya","gk","14","4","00","doang","ribu","trus","pengalihan","hidup","sda","90","nggak","dpr","cuman","12","d","beralih","kl","pks","lg","asli","september","ku","susah","kapitalisasi","detikcom","wa","mas","bilang","ojol","sdh","minggu","6","anggota","tdk","gimana","subsidibagikaumrentan","bansosharus","tepatsasaran","setuju","mahasiswa","bayar","jgn","sambo","rumah","minum","alphard","mesin","ri","askrlfess","gini","hati","gara","pindah","duit","eceran","video","lbh","bener","tinggal","alasan","dpt","ganti","dg","bantuan","anak","gua","dialihkan","cari","mikir","gas","loh","kasih","33","demokrat","wkwk","unjuk","kek","produk","sy","hr","erick","jakarta","kkpaccelerate","saktiwahyutrenggono","bansos","deh","eh","bagus","sosial","bangkitatautertindas","terdampak","kosong","ikn","hacker","jualan","cepat","rupiah","sulit","lihat","diisi","bbmuntuknelayan","sbyfess","150","untung","penyaluran","naiknya","nangis","irit","liat","aman","thohir","setara","persen","650","zalim","berasa","selengkapnya","gitu","17","malaysia","konsumsi","beat","bos","ganjarpranowo","menengah","hrg","mypertamina","univ","biaya","kayak","dikit","nelayan","mewah","id","cepet","masuk","guys","s","yaa","dampak","gila","mending","rendah","mu","pendapatan","dijual","rezim","mantap","terkait","goblok","pejabat","kondisi","kebutuhan","wib","hasil","lampung","merah","ngga","kegiatan","info","naikin","buruh","20","solusi","jaman","penjelasan","democrazymedia","jawa","dll","karna","ltr","super","skrng","fra050879","gara2","patraniagarjbt","naek","bau","kaga","anjlok","l","kemenbumn","pokok","hbd","alihsubsidiinflasiterkendali","100","tpi","pengg ...
